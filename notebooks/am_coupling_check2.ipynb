# %% [markdown]
# # Angular momentum coupling coefficients
#
# Use this `Notebook` to compare Clebsch-Gordan coefficients, Racah coefficients, and Wigner $9$-$j$ symbols calculated by Taro Tamura and published in the *TEST RUN OUTPUT* of the associated publication [1] with the corresponding results obtained using `PyGammaRAD` methods.  Wigner $9$-$j$ results calculated and published by Liqiang Wei [2] are also compared in this `Notebook`.

# %%
import PyGammaRAD as pg
am = pg.AngularMomentum()
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %% [markdown]
# ##  TEST RUN OUTPUT: Clebsch-Gordan Coefficients
#
# Check `DataFrame` results against documented output on p. 341 [1].  To calculate the Clebsch-Gordan coefficient using Eq. (1) of Ref. [1], the authors adopt the following convention:
#
# `IA` = 2$j_{1}$, `IB` = 2$j_{2}$, `IC` = 2$J$,
#
# `ID` = 2$m_{1}$, `IE` = 2$m_{2}$, `IF` = 2$M$.
#
# Accordingly, the `PyGammaRAD` method `cg` then takes the input as `cg(j1, m1, j2, m2, J, M)` in order to calculate the corresponding Clebsch-Gordan coefficient.

# %%
# Read Clebsch-Gordan test data from Tamura into DataFrame
cleb_df = pd.read_csv("test_csv_data/tamura_cleb_test.csv")
cleb_list = cleb_df.values.tolist()

# %%
# Create new DataFrame containing evaluated Clebsch-Gordan coefficients based on Tamura's input data
cg_column_names = ['IA', 'IB', 'IC', 'ID', 'IE', 'IF', 'C.G. COEFF']
cg_results_rows = []
for IX in cleb_list:
    IA = IX[0]
    IB = IX[1]
    IC = IX[2]
    ID = IX[3]
    IE = IX[4]
    IF = IX[5]

    j1 = IA/2
    j2 = IB/2
    J = IC/2
    m1 = ID/2
    m2 = IE/2
    M = IF/2

    cg_coeff = am.cg(j1,m1,j2,m2,J,M)
    #print(IA,IB,IC,ID,IE,IF,"%.6e"%cg_coeff)
    cg_results_rows.append([IA,IB,IC,ID,IE,IF,"%.6e"%cg_coeff])
cg_results_df = pd.DataFrame(cg_results_rows, columns=cg_column_names)
print(cg_results_df)
# Out:
#     IA  IB  IC  ID  IE  IF     C.G. COEFF
# 0    8   8   0   0   0   0   3.333333e-01
# 1    8   8   2   0   0   0   0.000000e+00
# 2    8   8   4   0   0   0  -3.798686e-01
# 3    8   8   6   0   0   0  -4.763503e-17
# 4    8   8   8   0   0   0   4.022911e-01
# 5    8   8  10   0   0   0   0.000000e+00
# 6    8   8  12   0   0   0  -4.494666e-01
# 7    8   8  14   0   0   0   0.000000e+00
# 8    8   8  16   0   0   0   6.170335e-01
# 9    5   7   4  -5   1  -4   1.992048e-01
# 10   5   7   4  -5   3  -2   3.857584e-01
# 11   5   7   4  -5   5   0   5.455447e-01
# 12   5   7   4  -5   7   2   5.892557e-01
# 13   5   7   4  -3  -1  -4  -3.563483e-01
# 14   5   7   4  -3   1  -2  -4.899789e-01
# 15   5   7   4  -3   3   0  -4.225771e-01
# 16   5   7   4  -3   5   2  -9.960238e-02
# 17   5   7   4  -3   7   4   5.270463e-01
# 18   5   7   4  -1  -3  -4   4.879500e-01
# 19   5   7   4  -1  -1  -2   4.409586e-01
# 20   5   7   4  -1   1   0   1.543033e-01
# 21   5   7   4  -1   3   2  -2.439750e-01
# 22   5   7   4  -1   5   4  -5.634362e-01
# 23   5   7   4   1  -5  -4  -5.634362e-01
# 24   5   7   4   1  -3  -2  -2.439750e-01
# 25   5   7   4   1  -1   0   1.543033e-01
# 26   5   7   4   1   1   2   4.409586e-01
# 27   5   7   4   1   3   4   4.879500e-01
# 28   5   7   4   3  -7  -4   5.270463e-01
# 29   5   7   4   3  -5  -2  -9.960238e-02
# 30   5   7   4   3  -3   0  -4.225771e-01
# 31   5   7   4   3  -1   2  -4.899789e-01
# 32   5   7   4   3   1   4  -3.563483e-01
# 33   5   7   4   5  -7  -2   5.892557e-01
# 34   5   7   4   5  -5   0   5.455447e-01
# 35   5   7   4   5  -3   2   3.857584e-01
# 36   5   7   4   5  -1   4   1.992048e-01

# %% [markdown]
# ##  TEST RUN OUTPUT: Racah Coefficients
#
# Check `DataFrame` results against documented output on p. 341-342 [1].  To calculate the Racah coefficient using Eq. (2) of Ref. [1], the authors adopt the following convention:
#
# `IA` = 2$a$, `IB` = 2$b$, `IC` = 2$c$,
#
# `ID` = 2$d$, `IE` = 2$e$, `IF` = 2$f$.
#
# Accordingly, the `PyGammaRAD` method `racah` then takes the input as `racah(a, b, c, d, e, f)` in order to calculate the corresponding Racah coefficient.

# %%
# Read Racah test data from Tamura into DataFrame
racah_df = pd.read_csv("test_csv_data/tamura_rac_test.csv")
racah_list = racah_df.values.tolist()

# %%
# Create new DataFrame containing evaluated Racah coefficients based on Tamura's input data
rac_column_names = ['IA', 'IB', 'IC', 'ID', 'IE', 'IF', 'RACAH COEFF']
rac_results_rows = []
for i,IX in enumerate(racah_list):
    
    IA = IX[0]
    IB = IX[1]
    IC = IX[2]
    ID = IX[3]
    IE = IX[4]
    IF = IX[5]

    a = IA/2
    b = IB/2
    c = IC/2
    d = ID/2
    e = IE/2
    f = IF/2

    rac_coeff = am.racah(a,b,c,d,e,f)
    #print(IA,IB,IC,ID,IE,IF,"%.6e"%rac_coeff)
    rac_results_rows.append([IA,IB,IC,ID,IE,IF,"%.6e"%rac_coeff])
rac_results_df = pd.DataFrame(rac_results_rows, columns=rac_column_names)
print(rac_results_df)
# Out:
#     IA  IB  IC  ID  IE  IF    RACAH COEFF
# 0    7   7   8   8   0   1  -1.178511e-01
# 1    7   7   8   8   0   3   1.178511e-01
# 2    7   7   8   8   0   5  -1.178511e-01
# 3    7   7   8   8   0   7   1.178511e-01
# 4    7   7   8   8   0   9  -1.178511e-01
# 5    7   7   8   8   0  11   1.178511e-01
# 6    7   7   8   8   0  13  -1.178511e-01
# 7    7   7   8   8   0  15   1.178511e-01
# 8    7   7   8   8   2   1   1.162028e-01
# 9    7   7   8   8   2   3  -1.062425e-01
# 10   7   7   8   8   2   5   8.964215e-02
# 11   7   7   8   8   2   7  -6.640159e-02
# 12   7   7   8   8   2   9   3.652087e-02
# 13   7   7   8   8   2  11   0.000000e+00
# 14   7   7   8   8   2  13  -4.316103e-02
# 15   7   7   8   8   2  15   9.296223e-02
# 16   7   7   8   8   4   1  -1.128339e-01
# 17   7   7   8   8   4   3   8.381944e-02
# 18   7   7   8   8   4   5  -4.132357e-02
# 19   7   7   8   8   4   7  -5.861500e-03
# 20   7   7   8   8   4   9   4.542662e-02
# 21   7   7   8   8   4  11  -6.154575e-02
# 22   7   7   8   8   4  13   3.487592e-02
# 23   7   7   8   8   4  15   5.744270e-02
# 24   7   7   8   8   6   1   1.075829e-01
# 25   7   7   8   8   6   3  -5.225454e-02
# 26   7   7   8   8   6   5  -1.201575e-02
# 27   7   7   8   8   6   7   5.309285e-02
# 28   7   7   8   8   6   9  -4.554807e-02
# 29   7   7   8   8   6  11  -9.780261e-03
# 30   7   7   8   8   6  13   6.063762e-02
# 31   7   7   8   8   6  15   2.738473e-02
# 32   7   7   8   8   8   1  -1.001542e-01
# 33   7   7   8   8   8   3   1.430774e-02
# 34   7   7   8   8   8   5   5.072745e-02
# 35   7   7   8   8   8   7  -4.162253e-02
# 36   7   7   8   8   8   9  -2.411305e-02
# 37   7   7   8   8   8  11   4.832615e-02
# 38   7   7   8   8   8  13   4.272312e-02
# 39   7   7   8   8   8  15   9.805306e-03
# 40   7   7   8   8  10   1   9.001029e-02
# 41   7   7   8   8  10   3   2.571722e-02
# 42   7   7   8   8  10   5  -5.494134e-02
# 43   7   7   8   8  10   7  -1.870344e-02
# 44   7   7   8   8  10   9   4.540979e-02
# 45   7   7   8   8  10  11   4.657875e-02
# 46   7   7   8   8  10  13   1.771431e-02
# 47   7   7   8   8  10  15   2.517770e-03
# 48   7   7   8   8  12   1  -7.607258e-02
# 49   7   7   8   8  12   3  -6.085806e-02
# 50   7   7   8   8  12   5   1.244824e-02
# 51   7   7   8   8  12   7   5.532551e-02
# 52   7   7   8   8  12   9   4.521797e-02
# 53   7   7   8   8  12  11   1.915114e-02
# 54   7   7   8   8  12  13   4.362204e-03
# 55   7   7   8   8  12  15   4.255809e-04
# 56   7   7   8   8  14   1   5.555556e-02
# 57   7   7   8   8  14   3   7.777778e-02
# 58   7   7   8   8  14   5   6.363636e-02
# 59   7   7   8   8  14   7   3.535354e-02
# 60   7   7   8   8  14   9   1.359751e-02
# 61   7   7   8   8  14  11   3.496503e-03
# 62   7   7   8   8  14  13   5.439005e-04
# 63   7   7   8   8  14  15   3.885004e-05

# %% [markdown]
# ##  TEST RUN OUTPUT: Wigner 9-$j$ symbols
#
# Check `DataFrame` results against documented output on p. 342 [1].  To evaluate the Wigner 9-$j$ symbol using Eq. (3) of Ref. [1], the authors adopt the following convention: `L9(N)` = 2$j_{n}$, thus,
#
# `L1` = 2$j_{1}$, `L2` = 2$j_{2}$, `L3` = 2$j_{4}$, `L4` = 2$j_{5}$, `L5` = 2$j_{3}$, `L6` = 2$j_{6}$, `L7` = 2$j_{7}$, `L8` = 2$j_{8}$, `L9` = 2$j_{9}$.
#
#
# Note the `L`/$j$ ordering with respect to the symbol defined in Eq. (3) [1] for input arguments $j_{5}$, $j_{3}$, and $j_{4}$.  Accordingly, the `PyGammaRAD` method `symb9j` then takes the input as `symb9j(j1,j2,j3,j4,j5,j6,j7,j8,j9)` in order to evaluate the corresponding Wigner 9-$j$ symbol.

# %%
# Read Wigner 9-j test data from Tamura into DataFrame
wigner9j_df = pd.read_csv("test_csv_data/tamura_9j_test.csv")
wigner9j_list = wigner9j_df.values.tolist()

# %%
# Create new DataFrame containing evaluated Wigner 9-j symbols based on Tamura's input data
wigner9j_column_names = ['L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7', 'L8', 'L9', 'WIGNER-9j SYMB']
wigner9j_results_rows = []
for i,IX in enumerate(wigner9j_list):
    
    L1 = IX[0]
    L2 = IX[1]
    L3 = IX[2]
    L4 = IX[3]
    L5 = IX[4]
    L6 = IX[5]
    L7 = IX[6]
    L8 = IX[7]
    L9 = IX[8]

    j1 = L1/2
    j2 = L2/2
    j3 = L5/2
    j4 = L3/2
    j5 = L4/2
    j6 = L6/2
    j7 = L7/2
    j8 = L8/2
    j9 = L9/2

    wigner9j_symb = am.symb9j(j1,j2,j3,j4,j5,j6,j7,j8,j9)
    #print(L1,L2,L3,L4,L5,L6,L7,L8,L9,"%.6e"%wigner9j_symb)
    wigner9j_results_rows.append([L1,L2,L3,L4,L5,L6,L7,L8,L9,"%.6e"%wigner9j_symb])
wigner9j_results_df = pd.DataFrame(wigner9j_results_rows, columns=wigner9j_column_names)
print(wigner9j_results_df)
# Out:
#    L1  L2  L3  L4  L5  L6  L7  L8  L9 WIGNER-9j SYMB
# 0   5   7   6   4   4   4   3   3   0   8.299250e-03
# 1   5   7   6   4   4   4   3   3   2  -1.137263e-02
# 2   5   7   6   4   4   4   3   3   4   1.223405e-02
# 3   5   7   6   4   4   4   3   3   6   3.249323e-03

# %% [markdown]
# ## Further Wigner 9-$j$ tests
#
# Use the following cells to test Wigner 9-$j$ results tabulated in Ref. [2] and compare execution times.

# %%
import time
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 120)

# %%
# Read Wigner 9-j test data from Lei into DataFrame
wigner9j_lei_df = pd.read_csv("test_csv_data/wei_9j_test.csv")
wigner9j_lei_list = wigner9j_lei_df.values.tolist()

# %%
wigner9j_lei_column_names = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'j', 'WIGNER-9j SYMB', 'CPU TIME [s]']
wigner9j_lei_results_rows = []
for i,IX in enumerate(wigner9j_lei_list):
    
    a = IX[0]
    b = IX[1]
    c = IX[2]
    d = IX[3]
    e = IX[4]
    f = IX[5]
    g = IX[6]
    h = IX[7]
    j = IX[8]

    start_time = time.perf_counter()
    wigner9j_symb = am.symb9j(a,b,c,d,e,f,g,h,j)
    stop_time = time.perf_counter()
    elapsed_time = stop_time - start_time
    #print(a,b,c,d,e,f,g,h,j,"%.15e"%wigner9j_symb,"%.7e"%elapsed_time)
    wigner9j_lei_results_rows.append([a,b,c,d,e,f,g,h,j,"%.15e"%wigner9j_symb,"%.7e"%elapsed_time])
wigner9j_lei_results_df = pd.DataFrame(wigner9j_lei_results_rows, columns=wigner9j_lei_column_names)
print(wigner9j_lei_results_df)
# Out:
#         a     b      c     d      e      f     g     h      j          WIGNER-9j SYMB   CPU TIME [s]
# 0     5.0   0.5    4.5   5.0    0.5    5.5   9.0   1.0   10.0   2.577867603707274e-03  2.1166000e-04
# 1    15.0  15.0   30.0  15.0    3.0   15.0  15.0  18.0   30.0   1.683847775115669e-04  5.8163800e-04
# 2    20.0  10.0   30.0  30.0   30.0   60.0  10.0  20.0   30.0   2.687449610319807e-04  7.2920500e-04
# 3    30.0  20.0   10.0  30.0   10.0   20.0  60.0  30.0   30.0   2.687449610319807e-04  8.8077200e-04
# 4    45.0  30.0   20.0  45.0   15.0   35.0  90.0  45.0   45.0  -6.511309679988229e-07  3.7762890e-03
# 5    50.0  51.0   52.0  53.0   54.0   55.0  56.0  57.0   58.0   4.188405993215843e-06  8.6438460e-02
# 6    74.0  67.0   60.0  82.0   60.0   70.0  10.0  20.0   30.0   4.944880489166700e-06  1.9818224e-02
# 7    84.0  90.0   61.0  60.0   64.0   40.0  52.0  40.0   30.0  -7.949170609614876e-08  2.4012008e-02
# 8    94.0  67.0   86.0  61.0   73.0   52.0  70.0  60.0   80.0  -1.868085775909687e-07  1.3263672e-01
# 9    60.0  70.0  115.0  50.0   70.0  110.0  60.0  50.0   40.0  -1.367996501230964e-06  4.2303630e-02
# 10  100.0  80.0   50.0  50.0  100.0   70.0  60.0  50.0  100.0   1.055977979556223e-07  7.2721557e-02

# %% [markdown]
# ## References
#
# [1] T. Tamura, *Angular Momentum Couplin Coefficients*, Comp. Phys. Comm., **1**, 337 (1970); https://doi.org/10.1016/0010-4655(70)90034-2
#
# [2] L. Wei, *New formula for 9-$j$ symbols and their direct calculation* Comput. Phys., **12**, 632 (1998); https://doi.org/10.1063/1.168745
